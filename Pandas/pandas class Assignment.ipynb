# %% [markdown]
# # importing libraires

# %%
import pandas as pd
import requests

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
type(data)
# Out:
# requests.models.Response

# %%
data1=data.json()

# %%
len(data1)
# Out:
# 30

# %%
type(data1)
# Out:
# list

# %%
data1[1]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46176',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46176/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46176/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46176/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/issues/46176',
#  'id': 1153565414,
#  'node_id': 'I_kwDOAA0YD85EwgLm',
#  'number': 46176,
#  'title': 'getsizeof  usage for memory utilization estimation is incompatible with PyPy',
#  'user': {'login': 'mach881040',
#   'id': 100502242,
#   'node_id': 'U_kgDOBf2K4g',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/100502242?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mach881040',
#   'html_url': 'https://github.com/mach881040',
# ...

# %%
data1[0]
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46177',
#  'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#  'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46177/labels{/name}',
#  'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46177/comments',
#  'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/46177/events',
#  'html_url': 'https://github.com/pandas-dev/pandas/pull/46177',
#  'id': 1153704239,
#  'node_id': 'PR_kwDOAA0YD84zpQlY',
#  'number': 46177,
#  'title': 'DOC: Move general utility functions to better locations',
#  'user': {'login': 'mroeschke',
#   'id': 10647082,
#   'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/mroeschke',
#   'html_url': 'https://github.com/mroeschke',
#   'followers_url': 'https://api.github.com/users/mroeschke/followers',
# ...

# %%
## make json file to dataframe
df = pd.DataFrame(data1, columns=['id', 'url', 'repository_url', 'labels_url', 'user'])
df.head()
# Out:
#            id                                                url  \
# 0  1153704239  https://api.github.com/repos/pandas-dev/pandas...
# 1  1153565414  https://api.github.com/repos/pandas-dev/pandas...
# 2  1153564804  https://api.github.com/repos/pandas-dev/pandas...
# 3  1153468610  https://api.github.com/repos/pandas-dev/pandas...
# 4  1153437571  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
# 3  https://api.github.com/repos/pandas-dev/pandas
# 4  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# 2  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
#now there are more data in "User" columns
#Final Code to Create Seperate Columns of "user"data

# %%
 df['user'].iloc[0]
# Out:
# {'login': 'mroeschke',
#  'id': 10647082,
#  'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/mroeschke',
#  'html_url': 'https://github.com/mroeschke',
#  'followers_url': 'https://api.github.com/users/mroeschke/followers',
#  'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#  'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#  'repos_url': 'https://api.github.com/users/mroeschke/repos',
#  'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#  'type': 'User',
# ...

# %%
 df['user'].iloc[1]
# Out:
# {'login': 'mach881040',
#  'id': 100502242,
#  'node_id': 'U_kgDOBf2K4g',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/100502242?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/mach881040',
#  'html_url': 'https://github.com/mach881040',
#  'followers_url': 'https://api.github.com/users/mach881040/followers',
#  'following_url': 'https://api.github.com/users/mach881040/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/mach881040/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/mach881040/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/mach881040/subscriptions',
#  'organizations_url': 'https://api.github.com/users/mach881040/orgs',
#  'repos_url': 'https://api.github.com/users/mach881040/repos',
#  'events_url': 'https://api.github.com/users/mach881040/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/mach881040/received_events',
#  'type': 'User',
# ...

# %%
 df['user'].iloc[3]
# Out:
# {'login': 'fractionalhare',
#  'id': 10540830,
#  'node_id': 'MDQ6VXNlcjEwNTQwODMw',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/10540830?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/fractionalhare',
#  'html_url': 'https://github.com/fractionalhare',
#  'followers_url': 'https://api.github.com/users/fractionalhare/followers',
#  'following_url': 'https://api.github.com/users/fractionalhare/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/fractionalhare/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/fractionalhare/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/fractionalhare/subscriptions',
#  'organizations_url': 'https://api.github.com/users/fractionalhare/orgs',
#  'repos_url': 'https://api.github.com/users/fractionalhare/repos',
#  'events_url': 'https://api.github.com/users/fractionalhare/events{/privacy}',
# ...

# %%
## etc
df['user'].iloc[4]
# Out:
# {'login': 'macsakow',
#  'id': 10297014,
#  'node_id': 'MDQ6VXNlcjEwMjk3MDE0',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/10297014?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/macsakow',
#  'html_url': 'https://github.com/macsakow',
#  'followers_url': 'https://api.github.com/users/macsakow/followers',
#  'following_url': 'https://api.github.com/users/macsakow/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/macsakow/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/macsakow/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/macsakow/subscriptions',
#  'organizations_url': 'https://api.github.com/users/macsakow/orgs',
#  'repos_url': 'https://api.github.com/users/macsakow/repos',
#  'events_url': 'https://api.github.com/users/macsakow/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/macsakow/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
for i in df['user'].iloc[0]:
    print(i,'----------')
# Out:
# login ----------
# id ----------
# node_id ----------
# avatar_url ----------
# gravatar_id ----------
# url ----------
# html_url ----------
# followers_url ----------
# following_url ----------
# gists_url ----------
# starred_url ----------
# subscriptions_url ----------
# organizations_url ----------
# repos_url ----------
# events_url ----------
# received_events_url ----------
# type ----------
# site_admin ----------

# %%
for i in df['user'].iloc[0]:
    print(i,'----------')
    for j in range(len(df)):
        if i=='id':
            print(df['user'].iloc[j][i])
        elif i=='url':
            print(df['user'].iloc[j][i])
        print(df['user'].iloc[j][i])
# Out:
# login ----------
# mroeschke
# mach881040
# jbrockmendel
# fractionalhare
# macsakow
# jbrockmendel
# Dr-Irv
# mroeschke
# weikhor
# J0
# lukemanley
# weikhor
# lukemanley
# milotoor
# tehunter
# jukiewiczm
# harahu
# mroeschke
# vnlitvinov
# weikhor
# timmy-ops
# mvashishtha
# mvashishtha
# McToel
# timlod
# Sleepingwell
# smarie
# benjamrio
# alanhowells
# DriesSchaumont
# id ----------
# 10647082
# 10647082
# 100502242
# 100502242
# 8078968
# 8078968
# 10540830
# 10540830
# 10297014
# 10297014
# 8078968
# 8078968
# 15113894
# 15113894
# 10647082
# 10647082
# 36619387
# 36619387
# 8011761
# 8011761
# 8519523
# 8519523
# 36619387
# 36619387
# 8519523
# 8519523
# 4667801
# 4667801
# 7980666
# 7980666
# 8179126
# 8179126
# 6145801
# 6145801
# 10647082
# 10647082
# 45396231
# 45396231
# 36619387
# 36619387
# 89028359
# 89028359
# 10712109
# 10712109
# 10712109
# 10712109
# 36071676
# 36071676
# 7346303
# 7346303
# 294943
# 294943
# 3236794
# 3236794
# 12810626
# 12810626
# 93594841
# ...

# %%
##Final Code to Create Seperate Columns
for i in df['user'].iloc[0]:
    lst = []
    for j in range(len(df)):
        lst.append(df['user'].iloc[j][i])
        
    if i =='id':
        df['user-id'] = lst  # Renaming the id to user-id so that we dont overwrite the existing id column
    elif i =='url':
        df['user-url'] = lst # Renaming the id to user-ur so that we dont overwrite the existing url column
        
    df[i] = lst  # Inserting all the values to respective colu

# %%
df
# Out:
#            id                                          url  \
# 0    10647082       https://api.github.com/users/mroeschke
# 1   100502242      https://api.github.com/users/mach881040
# 2     8078968    https://api.github.com/users/jbrockmendel
# 3    10540830  https://api.github.com/users/fractionalhare
# 4    10297014        https://api.github.com/users/macsakow
# 5     8078968    https://api.github.com/users/jbrockmendel
# 6    15113894          https://api.github.com/users/Dr-Irv
# 7    10647082       https://api.github.com/users/mroeschke
# 8    36619387         https://api.github.com/users/weikhor
# 9     8011761              https://api.github.com/users/J0
# 10    8519523      https://api.github.com/users/lukemanley
# 11   36619387         https://api.github.com/users/weikhor
# 12    8519523      https://api.github.com/users/lukemanley
# 13    4667801        https://api.github.com/users/milotoor
# 14    7980666        https://api.github.com/users/tehunter
# ...

# %%
df['user'].iloc[0]
# Out:
# {'login': 'mroeschke',
#  'id': 10647082,
#  'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/mroeschke',
#  'html_url': 'https://github.com/mroeschke',
#  'followers_url': 'https://api.github.com/users/mroeschke/followers',
#  'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#  'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#  'repos_url': 'https://api.github.com/users/mroeschke/repos',
#  'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#  'type': 'User',
# ...
